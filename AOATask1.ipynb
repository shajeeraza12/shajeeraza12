# %% [markdown]
# <a href="https://colab.research.google.com/github/shajeeraza12/shajeeraza12/blob/main/AOATask1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **The goal of this work is to experimentally analyze the time complexity of different algorithms by measuring execution times for various operations on vectors and matrices. The results will help compare the theoretical and practical performance of these algorithms.**
#
# **The problem involves generating random vectors and matrices of varying sizes and performing different operations such as sum, product, sorting, and matrix multiplication. The execution times of these operations will be measured and analyzed to study their time complexities and compare theoretical expectations with practical results.**

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

# %% [markdown]
# # 1) 𝑓(𝒗) = 𝑐𝑜𝑛𝑠𝑡 (constant function);
# # 2) 𝑓(𝒗) = ∑ 𝑣 (the sum of elements);
# # 3) 𝑓(𝒗) = ∏ 𝑣 (the product of elements);

# %% [markdown]
# The summation function calculates the total sum of elements in a vector, and has a time complexity of O(n). The multiplication function computes the product of vector elements, also with a time complexity of O(n). The constant function, which returns a fixed value regardless of the input, has a time complexity of O(1), as its execution time is constant.

# %%
# Function to generate an n-dimensional random vector
def generate_vector(n):
    return np.random.rand(n)

# Constant function that returns a constant value
def constant_function(vector):
    return 42

# Sum function that returns the sum of elements in the vector
def sum_function(vector):
    return np.sum(vector)

# Product function that returns the product of elements in the vector
def product_function(vector):
    return np.prod(vector)

# %%
# Initialize storage for execution times
execution_times_constant = []
execution_times_sum = []
execution_times_product = []

# %%
# Measure execution times for each function for each n in a single loop
for n in range(1, 2001):
    vector = generate_vector(n)

    # Measure time for all three functions in one loop
    start_time = time.perf_counter()
    for _ in range(5):
        _ = constant_function(vector)
    end_time = time.perf_counter()
    average_time_constant = (end_time - start_time) / 5
    execution_times_constant.append(average_time_constant)

    start_time = time.perf_counter()
    for _ in range(5):
        _ = sum_function(vector)
    end_time = time.perf_counter()
    average_time_sum = (end_time - start_time) / 5
    execution_times_sum.append(average_time_sum)

    start_time = time.perf_counter()
    for _ in range(5):
        _ = product_function(vector)
    end_time = time.perf_counter()
    average_time_product = (end_time - start_time) / 5
    execution_times_product.append(average_time_product)

# Plot the execution times for all three functions
plt.figure(figsize=(10, 6))
plt.plot(range(1, 2001), execution_times_constant, label="Constant Function", color="blue")
plt.plot(range(1, 2001), execution_times_sum, label="Sum Function", color="green")
plt.plot(range(1, 2001), execution_times_product, label="Product Function", color="red")

# Set labels and title
plt.xlabel("Vector Dimension (n)")
plt.ylabel("Average Execution Time (seconds)")
plt.title("Execution Time Comparison of Functions: Constant, Sum, Product")
plt.legend()
plt.grid(True)


plt.show()

# %% [markdown]
# The experimental results for the constant function align with the theoretical expectation of 𝑂(1), showing a constant execution time. Both the summation and multiplication functions follow the expected O(n) time complexity, with execution time increasing linearly with the vector size. While small deviations and spikes are observed, especially for multiplication, these could be caused by system load, memory caching, or the overhead of running the functions multiple times. However, the overall trend still confirms the theoretical complexities of O(1) for constant and O(n) for summation and multiplication.

# %% [markdown]
# # Sorting Algorithms
# # 1) Bubble Sort
# # 2) Quick Sort
# # 3) Time Sort

# %% [markdown]
# The sorting algorithms used in this task are Bubble Sort, Quick Sort, and Timsort. Bubble Sort repeatedly swaps adjacent elements to arrange them in order with O(n^2) complexity, while Quick Sort uses a divide-and-conquer approach with O(nlogn) average complexity, and Timsort combines merge and insertion sorts, achieving O(nlogn) in most cases.

# %%
# Bubble Sort implementation
def bubble_sort(vector):
    n = len(vector)
    for i in range(n):
        for j in range(0, n-i-1):
            if vector[j] > vector[j+1]:
                vector[j], vector[j+1] = vector[j+1], vector[j]

# Quick Sort implementation
def quick_sort(vector):
    if len(vector) <= 1:
        return vector
    pivot = vector[len(vector) // 2]
    left = [x for x in vector if x < pivot]
    middle = [x for x in vector if x == pivot]
    right = [x for x in vector if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# Timsort uses Python's built-in sorted() which is Timsort
def timsort(vector):
    return sorted(vector)

# Initialize storage for execution times
execution_times_bubble_sort = []
execution_times_quick_sort = []
execution_times_timsort = []

# %%
# Measure execution times for each sorting algorithm for each n in a single loop
for n in range(1, 2001):
    vector = generate_vector(n)

    # Measure time for bubble sort
    vector_copy = vector.copy()
    start_time = time.perf_counter()
    for _ in range(5):
        bubble_sort(vector_copy)
    end_time = time.perf_counter()
    average_time_bubble_sort = (end_time - start_time) / 5
    execution_times_bubble_sort.append(average_time_bubble_sort)

    # Measure time for quick sort
    vector_copy = vector.copy()
    start_time = time.perf_counter()
    for _ in range(5):
        quick_sort(vector_copy)
    end_time = time.perf_counter()
    average_time_quick_sort = (end_time - start_time) / 5
    execution_times_quick_sort.append(average_time_quick_sort)

    # Measure time for timsort (built-in Python sort)
    vector_copy = vector.copy()
    start_time = time.perf_counter()
    for _ in range(5):
        timsort(vector_copy)
    end_time = time.perf_counter()
    average_time_timsort = (end_time - start_time) / 5
    execution_times_timsort.append(average_time_timsort)

# Plot the execution times for all sorting algorithms
plt.figure(figsize=(12, 8))
plt.plot(range(1, 2001), execution_times_bubble_sort, label="Bubble Sort", color="orange")
plt.plot(range(1, 2001), execution_times_quick_sort, label="Quick Sort", color="purple")
plt.plot(range(1, 2001), execution_times_timsort, label="Timsort", color="brown")

# Set labels and title
plt.xlabel("Vector Dimension (n)")
plt.ylabel("Average Execution Time (seconds)")
plt.title("Execution Time Comparison of Sorting Algorithms (Bubble Sort, Quick Sort, Timsort)")
plt.legend()
plt.grid(True)


plt.show()

# %% [markdown]
# The experimental results show that Bubble Sort exhibits a significant increase in execution time, especially for larger vectors, consistent with its O(n^2) time complexity. In contrast, Quick Sort and Timsort demonstrate more efficient performance with execution times that increase much more gradually, in line with their O(nlogn) complexity.

# %% [markdown]
# # 4) supposing that the elements of 𝒗 are the coefficients of a polynomial 𝑃 of  degree 𝑛 −1,  calculate the value 𝑃(1.5) by a direct calculation of 𝑃(𝑥) =∑ 𝑣𝑥 (i.e. evaluating each term one by one) and by Horner’s method by representing the polynomial as P(𝑥) = 𝑣 +𝑥𝑣 +𝑥(𝑣 +⋯) ;

# %% [markdown]
# Direct calculation of a polynomial evaluates each term individually, with a time complexity of O(n) since each element of the vector is multiplied by a power of x. Horner's method, a more efficient approach, rewrites the polynomial to minimize redundant calculations, also with O(n) complexity but generally faster in practice due to fewer operations.

# %%
# Direct polynomial evaluation (sum of terms v_k * x^(k-1))
def direct_polynomial_evaluation(v, x=1.5):
    result = 0
    n = len(v)
    try:
        for k in range(1, n + 1):
            term = v[k-1] * (x ** (k - 1))
            result += term
    except OverflowError:
        print(f"Overflow occurred for n = {n}, x = {x}")
        result = np.inf
    return result

# Horner's method for polynomial evaluation
def horners_method(v, x=1.5):
    result = v[-1]
    for k in range(len(v) - 2, -1, -1):
        result = v[k] + x * result
    return result

# Initialize lists to store the execution times for each method
execution_times_direct = []
execution_times_horner = []

# %%
# Measure execution times for both methods for each n
for n in range(1, 2001):
    vector = generate_vector(n)

    # Measure time for direct polynomial evaluation
    start_time = time.perf_counter()
    for _ in range(5):
        _ = direct_polynomial_evaluation(vector)
    end_time = time.perf_counter()
    average_time_direct = (end_time - start_time) / 5
    execution_times_direct.append(average_time_direct)

    # Measure time for Horner's method
    start_time = time.perf_counter()
    for _ in range(5):
        _ = horners_method(vector)
    end_time = time.perf_counter()
    average_time_horner = (end_time - start_time) / 5
    execution_times_horner.append(average_time_horner)

# Plot the execution times for both methods
plt.figure(figsize=(10, 6))
plt.plot(range(1, 2001), execution_times_direct, label="Direct Method", color="blue")
plt.plot(range(1, 2001), execution_times_horner, label="Horner's Method", color="red")
plt.xlabel("Vector Dimension (n)")
plt.ylabel("Average Execution Time (seconds)")
plt.title("Execution Time Comparison: Direct Method vs Horner's Method")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-37-5775c01e2761>:8: RuntimeWarning: overflow encountered in scalar add
#   result += term
# <ipython-input-37-5775c01e2761>:18: RuntimeWarning: overflow encountered in scalar multiply
#   result = v[k] + x * result  # Nested evaluation: v_k + x * result
# Overflow occurred for n = 1752, x = 1.5
# Overflow occurred for n = 1752, x = 1.5
# Overflow occurred for n = 1752, x = 1.5
# Overflow occurred for n = 1752, x = 1.5
# Overflow occurred for n = 1752, x = 1.5
# Overflow occurred for n = 1753, x = 1.5
# Overflow occurred for n = 1753, x = 1.5
# Overflow occurred for n = 1753, x = 1.5
# Overflow occurred for n = 1753, x = 1.5
# Overflow occurred for n = 1753, x = 1.5
# Overflow occurred for n = 1754, x = 1.5
# Overflow occurred for n = 1754, x = 1.5
# Overflow occurred for n = 1754, x = 1.5
# Overflow occurred for n = 1754, x = 1.5
# Overflow occurred for n = 1754, x = 1.5
# Overflow occurred for n = 1755, x = 1.5
# Overflow occurred for n = 1755, x = 1.5
# Overflow occurred for n = 1755, x = 1.5
# Overflow occurred for n = 1755, x = 1.5
# Overflow occurred for n = 1755, x = 1.5
# Overflow occurred for n = 1756, x = 1.5
# Overflow occurred for n = 1756, x = 1.5
# Overflow occurred for n = 1756, x = 1.5
# Overflow occurred for n = 1756, x = 1.5
# Overflow occurred for n = 1756, x = 1.5
# Overflow occurred for n = 1757, x = 1.5
# Overflow occurred for n = 1757, x = 1.5
# Overflow occurred for n = 1757, x = 1.5
# Overflow occurred for n = 1757, x = 1.5
# Overflow occurred for n = 1757, x = 1.5
# Overflow occurred for n = 1758, x = 1.5
# Overflow occurred for n = 1758, x = 1.5
# Overflow occurred for n = 1758, x = 1.5
# Overflow occurred for n = 1758, x = 1.5
# Overflow occurred for n = 1758, x = 1.5
# Overflow occurred for n = 1759, x = 1.5
# Overflow occurred for n = 1759, x = 1.5
# Overflow occurred for n = 1759, x = 1.5
# Overflow occurred for n = 1759, x = 1.5
# Overflow occurred for n = 1759, x = 1.5
# Overflow occurred for n = 1760, x = 1.5
# Overflow occurred for n = 1760, x = 1.5
# Overflow occurred for n = 1760, x = 1.5
# Overflow occurred for n = 1760, x = 1.5
# Overflow occurred for n = 1760, x = 1.5
# Overflow occurred for n = 1761, x = 1.5
# Overflow occurred for n = 1761, x = 1.5
# Overflow occurred for n = 1761, x = 1.5
# Overflow occurred for n = 1761, x = 1.5
# Overflow occurred for n = 1761, x = 1.5
# Overflow occurred for n = 1762, x = 1.5
# Overflow occurred for n = 1762, x = 1.5
# Overflow occurred for n = 1762, x = 1.5
# Overflow occurred for n = 1762, x = 1.5
# Overflow occurred for n = 1762, x = 1.5
# Overflow occurred for n = 1763, x = 1.5
# Overflow occurred for n = 1763, x = 1.5
# Overflow occurred for n = 1763, x = 1.5
# Overflow occurred for n = 1763, x = 1.5
# Overflow occurred for n = 1763, x = 1.5
# Overflow occurred for n = 1764, x = 1.5
# Overflow occurred for n = 1764, x = 1.5
# Overflow occurred for n = 1764, x = 1.5
# Overflow occurred for n = 1764, x = 1.5
# Overflow occurred for n = 1764, x = 1.5
# Overflow occurred for n = 1765, x = 1.5
# Overflow occurred for n = 1765, x = 1.5
# Overflow occurred for n = 1765, x = 1.5
# Overflow occurred for n = 1765, x = 1.5
# Overflow occurred for n = 1765, x = 1.5
# Overflow occurred for n = 1766, x = 1.5
# Overflow occurred for n = 1766, x = 1.5
# Overflow occurred for n = 1766, x = 1.5
# Overflow occurred for n = 1766, x = 1.5
# Overflow occurred for n = 1766, x = 1.5
# Overflow occurred for n = 1767, x = 1.5
# Overflow occurred for n = 1767, x = 1.5
# Overflow occurred for n = 1767, x = 1.5
# Overflow occurred for n = 1767, x = 1.5
# Overflow occurred for n = 1767, x = 1.5
# Overflow occurred for n = 1768, x = 1.5
# Overflow occurred for n = 1768, x = 1.5
# Overflow occurred for n = 1768, x = 1.5
# Overflow occurred for n = 1768, x = 1.5
# Overflow occurred for n = 1768, x = 1.5
# Overflow occurred for n = 1769, x = 1.5
# Overflow occurred for n = 1769, x = 1.5
# Overflow occurred for n = 1769, x = 1.5
# Overflow occurred for n = 1769, x = 1.5
# Overflow occurred for n = 1769, x = 1.5
# Overflow occurred for n = 1770, x = 1.5
# Overflow occurred for n = 1770, x = 1.5
# Overflow occurred for n = 1770, x = 1.5
# Overflow occurred for n = 1770, x = 1.5
# Overflow occurred for n = 1770, x = 1.5
# Overflow occurred for n = 1771, x = 1.5
# Overflow occurred for n = 1771, x = 1.5
# Overflow occurred for n = 1771, x = 1.5
# Overflow occurred for n = 1771, x = 1.5
# Overflow occurred for n = 1771, x = 1.5
# Overflow occurred for n = 1772, x = 1.5
# Overflow occurred for n = 1772, x = 1.5
# Overflow occurred for n = 1772, x = 1.5
# Overflow occurred for n = 1772, x = 1.5
# Overflow occurred for n = 1772, x = 1.5
# Overflow occurred for n = 1773, x = 1.5
# Overflow occurred for n = 1773, x = 1.5
# Overflow occurred for n = 1773, x = 1.5
# Overflow occurred for n = 1773, x = 1.5
# Overflow occurred for n = 1773, x = 1.5
# Overflow occurred for n = 1774, x = 1.5
# Overflow occurred for n = 1774, x = 1.5
# Overflow occurred for n = 1774, x = 1.5
# Overflow occurred for n = 1774, x = 1.5
# Overflow occurred for n = 1774, x = 1.5
# Overflow occurred for n = 1775, x = 1.5
# Overflow occurred for n = 1775, x = 1.5
# Overflow occurred for n = 1775, x = 1.5
# Overflow occurred for n = 1775, x = 1.5
# Overflow occurred for n = 1775, x = 1.5
# Overflow occurred for n = 1776, x = 1.5
# Overflow occurred for n = 1776, x = 1.5
# Overflow occurred for n = 1776, x = 1.5
# Overflow occurred for n = 1776, x = 1.5
# Overflow occurred for n = 1776, x = 1.5
# Overflow occurred for n = 1777, x = 1.5
# Overflow occurred for n = 1777, x = 1.5
# Overflow occurred for n = 1777, x = 1.5
# Overflow occurred for n = 1777, x = 1.5
# Overflow occurred for n = 1777, x = 1.5
# Overflow occurred for n = 1778, x = 1.5
# Overflow occurred for n = 1778, x = 1.5
# Overflow occurred for n = 1778, x = 1.5
# Overflow occurred for n = 1778, x = 1.5
# Overflow occurred for n = 1778, x = 1.5
# Overflow occurred for n = 1779, x = 1.5
# Overflow occurred for n = 1779, x = 1.5
# Overflow occurred for n = 1779, x = 1.5
# Overflow occurred for n = 1779, x = 1.5
# Overflow occurred for n = 1779, x = 1.5
# Overflow occurred for n = 1780, x = 1.5
# Overflow occurred for n = 1780, x = 1.5
# Overflow occurred for n = 1780, x = 1.5
# Overflow occurred for n = 1780, x = 1.5
# Overflow occurred for n = 1780, x = 1.5
# Overflow occurred for n = 1781, x = 1.5
# Overflow occurred for n = 1781, x = 1.5
# Overflow occurred for n = 1781, x = 1.5
# Overflow occurred for n = 1781, x = 1.5
# Overflow occurred for n = 1781, x = 1.5
# Overflow occurred for n = 1782, x = 1.5
# Overflow occurred for n = 1782, x = 1.5
# Overflow occurred for n = 1782, x = 1.5
# Overflow occurred for n = 1782, x = 1.5
# Overflow occurred for n = 1782, x = 1.5
# Overflow occurred for n = 1783, x = 1.5
# Overflow occurred for n = 1783, x = 1.5
# Overflow occurred for n = 1783, x = 1.5
# Overflow occurred for n = 1783, x = 1.5
# Overflow occurred for n = 1783, x = 1.5
# Overflow occurred for n = 1784, x = 1.5
# Overflow occurred for n = 1784, x = 1.5
# Overflow occurred for n = 1784, x = 1.5
# Overflow occurred for n = 1784, x = 1.5
# Overflow occurred for n = 1784, x = 1.5
# Overflow occurred for n = 1785, x = 1.5
# Overflow occurred for n = 1785, x = 1.5
# Overflow occurred for n = 1785, x = 1.5
# Overflow occurred for n = 1785, x = 1.5
# Overflow occurred for n = 1785, x = 1.5
# Overflow occurred for n = 1786, x = 1.5
# Overflow occurred for n = 1786, x = 1.5
# Overflow occurred for n = 1786, x = 1.5
# Overflow occurred for n = 1786, x = 1.5
# Overflow occurred for n = 1786, x = 1.5
# Overflow occurred for n = 1787, x = 1.5
# Overflow occurred for n = 1787, x = 1.5
# Overflow occurred for n = 1787, x = 1.5
# Overflow occurred for n = 1787, x = 1.5
# Overflow occurred for n = 1787, x = 1.5
# Overflow occurred for n = 1788, x = 1.5
# Overflow occurred for n = 1788, x = 1.5
# Overflow occurred for n = 1788, x = 1.5
# Overflow occurred for n = 1788, x = 1.5
# Overflow occurred for n = 1788, x = 1.5
# Overflow occurred for n = 1789, x = 1.5
# Overflow occurred for n = 1789, x = 1.5
# Overflow occurred for n = 1789, x = 1.5
# Overflow occurred for n = 1789, x = 1.5
# Overflow occurred for n = 1789, x = 1.5
# Overflow occurred for n = 1790, x = 1.5
# Overflow occurred for n = 1790, x = 1.5
# Overflow occurred for n = 1790, x = 1.5
# Overflow occurred for n = 1790, x = 1.5
# Overflow occurred for n = 1790, x = 1.5
# Overflow occurred for n = 1791, x = 1.5
# Overflow occurred for n = 1791, x = 1.5
# Overflow occurred for n = 1791, x = 1.5
# Overflow occurred for n = 1791, x = 1.5
# Overflow occurred for n = 1791, x = 1.5
# Overflow occurred for n = 1792, x = 1.5
# Overflow occurred for n = 1792, x = 1.5
# Overflow occurred for n = 1792, x = 1.5
# Overflow occurred for n = 1792, x = 1.5
# Overflow occurred for n = 1792, x = 1.5
# Overflow occurred for n = 1793, x = 1.5
# Overflow occurred for n = 1793, x = 1.5
# Overflow occurred for n = 1793, x = 1.5
# Overflow occurred for n = 1793, x = 1.5
# Overflow occurred for n = 1793, x = 1.5
# Overflow occurred for n = 1794, x = 1.5
# Overflow occurred for n = 1794, x = 1.5
# Overflow occurred for n = 1794, x = 1.5
# Overflow occurred for n = 1794, x = 1.5
# Overflow occurred for n = 1794, x = 1.5
# Overflow occurred for n = 1795, x = 1.5
# Overflow occurred for n = 1795, x = 1.5
# Overflow occurred for n = 1795, x = 1.5
# Overflow occurred for n = 1795, x = 1.5
# Overflow occurred for n = 1795, x = 1.5
# Overflow occurred for n = 1796, x = 1.5
# Overflow occurred for n = 1796, x = 1.5
# Overflow occurred for n = 1796, x = 1.5
# Overflow occurred for n = 1796, x = 1.5
# Overflow occurred for n = 1796, x = 1.5
# Overflow occurred for n = 1797, x = 1.5
# Overflow occurred for n = 1797, x = 1.5
# Overflow occurred for n = 1797, x = 1.5
# Overflow occurred for n = 1797, x = 1.5
# Overflow occurred for n = 1797, x = 1.5
# Overflow occurred for n = 1798, x = 1.5
# Overflow occurred for n = 1798, x = 1.5
# Overflow occurred for n = 1798, x = 1.5
# Overflow occurred for n = 1798, x = 1.5
# Overflow occurred for n = 1798, x = 1.5
# Overflow occurred for n = 1799, x = 1.5
# Overflow occurred for n = 1799, x = 1.5
# Overflow occurred for n = 1799, x = 1.5
# Overflow occurred for n = 1799, x = 1.5
# Overflow occurred for n = 1799, x = 1.5
# Overflow occurred for n = 1800, x = 1.5
# Overflow occurred for n = 1800, x = 1.5
# Overflow occurred for n = 1800, x = 1.5
# Overflow occurred for n = 1800, x = 1.5
# Overflow occurred for n = 1800, x = 1.5
# Overflow occurred for n = 1801, x = 1.5
# Overflow occurred for n = 1801, x = 1.5
# Overflow occurred for n = 1801, x = 1.5
# Overflow occurred for n = 1801, x = 1.5
# Overflow occurred for n = 1801, x = 1.5
# Overflow occurred for n = 1802, x = 1.5
# Overflow occurred for n = 1802, x = 1.5
# Overflow occurred for n = 1802, x = 1.5
# Overflow occurred for n = 1802, x = 1.5
# Overflow occurred for n = 1802, x = 1.5
# Overflow occurred for n = 1803, x = 1.5
# Overflow occurred for n = 1803, x = 1.5
# Overflow occurred for n = 1803, x = 1.5
# Overflow occurred for n = 1803, x = 1.5
# Overflow occurred for n = 1803, x = 1.5
# Overflow occurred for n = 1804, x = 1.5
# Overflow occurred for n = 1804, x = 1.5
# Overflow occurred for n = 1804, x = 1.5
# Overflow occurred for n = 1804, x = 1.5
# Overflow occurred for n = 1804, x = 1.5
# Overflow occurred for n = 1805, x = 1.5
# Overflow occurred for n = 1805, x = 1.5
# Overflow occurred for n = 1805, x = 1.5
# Overflow occurred for n = 1805, x = 1.5
# Overflow occurred for n = 1805, x = 1.5
# Overflow occurred for n = 1806, x = 1.5
# Overflow occurred for n = 1806, x = 1.5
# Overflow occurred for n = 1806, x = 1.5
# Overflow occurred for n = 1806, x = 1.5
# Overflow occurred for n = 1806, x = 1.5
# Overflow occurred for n = 1807, x = 1.5
# Overflow occurred for n = 1807, x = 1.5
# Overflow occurred for n = 1807, x = 1.5
# Overflow occurred for n = 1807, x = 1.5
# Overflow occurred for n = 1807, x = 1.5
# Overflow occurred for n = 1808, x = 1.5
# Overflow occurred for n = 1808, x = 1.5
# Overflow occurred for n = 1808, x = 1.5
# Overflow occurred for n = 1808, x = 1.5
# Overflow occurred for n = 1808, x = 1.5
# Overflow occurred for n = 1809, x = 1.5
# Overflow occurred for n = 1809, x = 1.5
# Overflow occurred for n = 1809, x = 1.5
# Overflow occurred for n = 1809, x = 1.5
# Overflow occurred for n = 1809, x = 1.5
# Overflow occurred for n = 1810, x = 1.5
# Overflow occurred for n = 1810, x = 1.5
# Overflow occurred for n = 1810, x = 1.5
# Overflow occurred for n = 1810, x = 1.5
# Overflow occurred for n = 1810, x = 1.5
# Overflow occurred for n = 1811, x = 1.5
# Overflow occurred for n = 1811, x = 1.5
# Overflow occurred for n = 1811, x = 1.5
# Overflow occurred for n = 1811, x = 1.5
# Overflow occurred for n = 1811, x = 1.5
# Overflow occurred for n = 1812, x = 1.5
# Overflow occurred for n = 1812, x = 1.5
# Overflow occurred for n = 1812, x = 1.5
# Overflow occurred for n = 1812, x = 1.5
# Overflow occurred for n = 1812, x = 1.5
# Overflow occurred for n = 1813, x = 1.5
# Overflow occurred for n = 1813, x = 1.5
# Overflow occurred for n = 1813, x = 1.5
# Overflow occurred for n = 1813, x = 1.5
# Overflow occurred for n = 1813, x = 1.5
# Overflow occurred for n = 1814, x = 1.5
# Overflow occurred for n = 1814, x = 1.5
# Overflow occurred for n = 1814, x = 1.5
# Overflow occurred for n = 1814, x = 1.5
# Overflow occurred for n = 1814, x = 1.5
# Overflow occurred for n = 1815, x = 1.5
# Overflow occurred for n = 1815, x = 1.5
# Overflow occurred for n = 1815, x = 1.5
# Overflow occurred for n = 1815, x = 1.5
# Overflow occurred for n = 1815, x = 1.5
# Overflow occurred for n = 1816, x = 1.5
# Overflow occurred for n = 1816, x = 1.5
# Overflow occurred for n = 1816, x = 1.5
# Overflow occurred for n = 1816, x = 1.5
# Overflow occurred for n = 1816, x = 1.5
# Overflow occurred for n = 1817, x = 1.5
# Overflow occurred for n = 1817, x = 1.5
# Overflow occurred for n = 1817, x = 1.5
# Overflow occurred for n = 1817, x = 1.5
# Overflow occurred for n = 1817, x = 1.5
# Overflow occurred for n = 1818, x = 1.5
# Overflow occurred for n = 1818, x = 1.5
# Overflow occurred for n = 1818, x = 1.5
# Overflow occurred for n = 1818, x = 1.5
# Overflow occurred for n = 1818, x = 1.5
# Overflow occurred for n = 1819, x = 1.5
# Overflow occurred for n = 1819, x = 1.5
# Overflow occurred for n = 1819, x = 1.5
# Overflow occurred for n = 1819, x = 1.5
# Overflow occurred for n = 1819, x = 1.5
# Overflow occurred for n = 1820, x = 1.5
# Overflow occurred for n = 1820, x = 1.5
# Overflow occurred for n = 1820, x = 1.5
# Overflow occurred for n = 1820, x = 1.5
# Overflow occurred for n = 1820, x = 1.5
# Overflow occurred for n = 1821, x = 1.5
# Overflow occurred for n = 1821, x = 1.5
# Overflow occurred for n = 1821, x = 1.5
# Overflow occurred for n = 1821, x = 1.5
# Overflow occurred for n = 1821, x = 1.5
# Overflow occurred for n = 1822, x = 1.5
# Overflow occurred for n = 1822, x = 1.5
# Overflow occurred for n = 1822, x = 1.5
# Overflow occurred for n = 1822, x = 1.5
# Overflow occurred for n = 1822, x = 1.5
# Overflow occurred for n = 1823, x = 1.5
# Overflow occurred for n = 1823, x = 1.5
# Overflow occurred for n = 1823, x = 1.5
# Overflow occurred for n = 1823, x = 1.5
# Overflow occurred for n = 1823, x = 1.5
# Overflow occurred for n = 1824, x = 1.5
# Overflow occurred for n = 1824, x = 1.5
# Overflow occurred for n = 1824, x = 1.5
# Overflow occurred for n = 1824, x = 1.5
# Overflow occurred for n = 1824, x = 1.5
# Overflow occurred for n = 1825, x = 1.5
# Overflow occurred for n = 1825, x = 1.5
# Overflow occurred for n = 1825, x = 1.5
# Overflow occurred for n = 1825, x = 1.5
# Overflow occurred for n = 1825, x = 1.5
# Overflow occurred for n = 1826, x = 1.5
# Overflow occurred for n = 1826, x = 1.5
# Overflow occurred for n = 1826, x = 1.5
# Overflow occurred for n = 1826, x = 1.5
# Overflow occurred for n = 1826, x = 1.5
# Overflow occurred for n = 1827, x = 1.5
# Overflow occurred for n = 1827, x = 1.5
# Overflow occurred for n = 1827, x = 1.5
# Overflow occurred for n = 1827, x = 1.5
# Overflow occurred for n = 1827, x = 1.5
# Overflow occurred for n = 1828, x = 1.5
# Overflow occurred for n = 1828, x = 1.5
# Overflow occurred for n = 1828, x = 1.5
# Overflow occurred for n = 1828, x = 1.5
# Overflow occurred for n = 1828, x = 1.5
# Overflow occurred for n = 1829, x = 1.5
# Overflow occurred for n = 1829, x = 1.5
# Overflow occurred for n = 1829, x = 1.5
# Overflow occurred for n = 1829, x = 1.5
# Overflow occurred for n = 1829, x = 1.5
# Overflow occurred for n = 1830, x = 1.5
# Overflow occurred for n = 1830, x = 1.5
# Overflow occurred for n = 1830, x = 1.5
# Overflow occurred for n = 1830, x = 1.5
# Overflow occurred for n = 1830, x = 1.5
# Overflow occurred for n = 1831, x = 1.5
# Overflow occurred for n = 1831, x = 1.5
# Overflow occurred for n = 1831, x = 1.5
# Overflow occurred for n = 1831, x = 1.5
# Overflow occurred for n = 1831, x = 1.5
# Overflow occurred for n = 1832, x = 1.5
# Overflow occurred for n = 1832, x = 1.5
# Overflow occurred for n = 1832, x = 1.5
# Overflow occurred for n = 1832, x = 1.5
# Overflow occurred for n = 1832, x = 1.5
# Overflow occurred for n = 1833, x = 1.5
# Overflow occurred for n = 1833, x = 1.5
# Overflow occurred for n = 1833, x = 1.5
# Overflow occurred for n = 1833, x = 1.5
# Overflow occurred for n = 1833, x = 1.5
# Overflow occurred for n = 1834, x = 1.5
# Overflow occurred for n = 1834, x = 1.5
# Overflow occurred for n = 1834, x = 1.5
# Overflow occurred for n = 1834, x = 1.5
# Overflow occurred for n = 1834, x = 1.5
# Overflow occurred for n = 1835, x = 1.5
# Overflow occurred for n = 1835, x = 1.5
# Overflow occurred for n = 1835, x = 1.5
# Overflow occurred for n = 1835, x = 1.5
# Overflow occurred for n = 1835, x = 1.5
# Overflow occurred for n = 1836, x = 1.5
# Overflow occurred for n = 1836, x = 1.5
# Overflow occurred for n = 1836, x = 1.5
# Overflow occurred for n = 1836, x = 1.5
# Overflow occurred for n = 1836, x = 1.5
# Overflow occurred for n = 1837, x = 1.5
# Overflow occurred for n = 1837, x = 1.5
# Overflow occurred for n = 1837, x = 1.5
# Overflow occurred for n = 1837, x = 1.5
# Overflow occurred for n = 1837, x = 1.5
# Overflow occurred for n = 1838, x = 1.5
# Overflow occurred for n = 1838, x = 1.5
# Overflow occurred for n = 1838, x = 1.5
# Overflow occurred for n = 1838, x = 1.5
# Overflow occurred for n = 1838, x = 1.5
# Overflow occurred for n = 1839, x = 1.5
# Overflow occurred for n = 1839, x = 1.5
# Overflow occurred for n = 1839, x = 1.5
# Overflow occurred for n = 1839, x = 1.5
# Overflow occurred for n = 1839, x = 1.5
# Overflow occurred for n = 1840, x = 1.5
# Overflow occurred for n = 1840, x = 1.5
# Overflow occurred for n = 1840, x = 1.5
# Overflow occurred for n = 1840, x = 1.5
# Overflow occurred for n = 1840, x = 1.5
# Overflow occurred for n = 1841, x = 1.5
# Overflow occurred for n = 1841, x = 1.5
# Overflow occurred for n = 1841, x = 1.5
# Overflow occurred for n = 1841, x = 1.5
# Overflow occurred for n = 1841, x = 1.5
# Overflow occurred for n = 1842, x = 1.5
# Overflow occurred for n = 1842, x = 1.5
# Overflow occurred for n = 1842, x = 1.5
# Overflow occurred for n = 1842, x = 1.5
# Overflow occurred for n = 1842, x = 1.5
# Overflow occurred for n = 1843, x = 1.5
# Overflow occurred for n = 1843, x = 1.5
# Overflow occurred for n = 1843, x = 1.5
# Overflow occurred for n = 1843, x = 1.5
# Overflow occurred for n = 1843, x = 1.5
# Overflow occurred for n = 1844, x = 1.5
# Overflow occurred for n = 1844, x = 1.5
# Overflow occurred for n = 1844, x = 1.5
# Overflow occurred for n = 1844, x = 1.5
# Overflow occurred for n = 1844, x = 1.5
# Overflow occurred for n = 1845, x = 1.5
# Overflow occurred for n = 1845, x = 1.5
# Overflow occurred for n = 1845, x = 1.5
# Overflow occurred for n = 1845, x = 1.5
# Overflow occurred for n = 1845, x = 1.5
# Overflow occurred for n = 1846, x = 1.5
# Overflow occurred for n = 1846, x = 1.5
# Overflow occurred for n = 1846, x = 1.5
# Overflow occurred for n = 1846, x = 1.5
# Overflow occurred for n = 1846, x = 1.5
# Overflow occurred for n = 1847, x = 1.5
# Overflow occurred for n = 1847, x = 1.5
# Overflow occurred for n = 1847, x = 1.5
# Overflow occurred for n = 1847, x = 1.5
# Overflow occurred for n = 1847, x = 1.5
# Overflow occurred for n = 1848, x = 1.5
# Overflow occurred for n = 1848, x = 1.5
# Overflow occurred for n = 1848, x = 1.5
# Overflow occurred for n = 1848, x = 1.5
# Overflow occurred for n = 1848, x = 1.5
# Overflow occurred for n = 1849, x = 1.5
# Overflow occurred for n = 1849, x = 1.5
# Overflow occurred for n = 1849, x = 1.5
# Overflow occurred for n = 1849, x = 1.5
# Overflow occurred for n = 1849, x = 1.5
# Overflow occurred for n = 1850, x = 1.5
# Overflow occurred for n = 1850, x = 1.5
# Overflow occurred for n = 1850, x = 1.5
# Overflow occurred for n = 1850, x = 1.5
# Overflow occurred for n = 1850, x = 1.5
# Overflow occurred for n = 1851, x = 1.5
# Overflow occurred for n = 1851, x = 1.5
# Overflow occurred for n = 1851, x = 1.5
# Overflow occurred for n = 1851, x = 1.5
# Overflow occurred for n = 1851, x = 1.5
# Overflow occurred for n = 1852, x = 1.5
# Overflow occurred for n = 1852, x = 1.5
# Overflow occurred for n = 1852, x = 1.5
# Overflow occurred for n = 1852, x = 1.5
# Overflow occurred for n = 1852, x = 1.5
# Overflow occurred for n = 1853, x = 1.5
# Overflow occurred for n = 1853, x = 1.5
# Overflow occurred for n = 1853, x = 1.5
# Overflow occurred for n = 1853, x = 1.5
# Overflow occurred for n = 1853, x = 1.5
# Overflow occurred for n = 1854, x = 1.5
# Overflow occurred for n = 1854, x = 1.5
# Overflow occurred for n = 1854, x = 1.5
# Overflow occurred for n = 1854, x = 1.5
# Overflow occurred for n = 1854, x = 1.5
# Overflow occurred for n = 1855, x = 1.5
# Overflow occurred for n = 1855, x = 1.5
# Overflow occurred for n = 1855, x = 1.5
# Overflow occurred for n = 1855, x = 1.5
# Overflow occurred for n = 1855, x = 1.5
# Overflow occurred for n = 1856, x = 1.5
# Overflow occurred for n = 1856, x = 1.5
# Overflow occurred for n = 1856, x = 1.5
# Overflow occurred for n = 1856, x = 1.5
# Overflow occurred for n = 1856, x = 1.5
# Overflow occurred for n = 1857, x = 1.5
# Overflow occurred for n = 1857, x = 1.5
# Overflow occurred for n = 1857, x = 1.5
# Overflow occurred for n = 1857, x = 1.5
# Overflow occurred for n = 1857, x = 1.5
# Overflow occurred for n = 1858, x = 1.5
# Overflow occurred for n = 1858, x = 1.5
# Overflow occurred for n = 1858, x = 1.5
# Overflow occurred for n = 1858, x = 1.5
# Overflow occurred for n = 1858, x = 1.5
# Overflow occurred for n = 1859, x = 1.5
# Overflow occurred for n = 1859, x = 1.5
# Overflow occurred for n = 1859, x = 1.5
# Overflow occurred for n = 1859, x = 1.5
# Overflow occurred for n = 1859, x = 1.5
# Overflow occurred for n = 1860, x = 1.5
# Overflow occurred for n = 1860, x = 1.5
# Overflow occurred for n = 1860, x = 1.5
# Overflow occurred for n = 1860, x = 1.5
# Overflow occurred for n = 1860, x = 1.5
# Overflow occurred for n = 1861, x = 1.5
# Overflow occurred for n = 1861, x = 1.5
# Overflow occurred for n = 1861, x = 1.5
# Overflow occurred for n = 1861, x = 1.5
# Overflow occurred for n = 1861, x = 1.5
# Overflow occurred for n = 1862, x = 1.5
# Overflow occurred for n = 1862, x = 1.5
# Overflow occurred for n = 1862, x = 1.5
# Overflow occurred for n = 1862, x = 1.5
# Overflow occurred for n = 1862, x = 1.5
# Overflow occurred for n = 1863, x = 1.5
# Overflow occurred for n = 1863, x = 1.5
# Overflow occurred for n = 1863, x = 1.5
# Overflow occurred for n = 1863, x = 1.5
# Overflow occurred for n = 1863, x = 1.5
# Overflow occurred for n = 1864, x = 1.5
# Overflow occurred for n = 1864, x = 1.5
# Overflow occurred for n = 1864, x = 1.5
# Overflow occurred for n = 1864, x = 1.5
# Overflow occurred for n = 1864, x = 1.5
# Overflow occurred for n = 1865, x = 1.5
# Overflow occurred for n = 1865, x = 1.5
# Overflow occurred for n = 1865, x = 1.5
# Overflow occurred for n = 1865, x = 1.5
# Overflow occurred for n = 1865, x = 1.5
# Overflow occurred for n = 1866, x = 1.5
# Overflow occurred for n = 1866, x = 1.5
# Overflow occurred for n = 1866, x = 1.5
# Overflow occurred for n = 1866, x = 1.5
# Overflow occurred for n = 1866, x = 1.5
# Overflow occurred for n = 1867, x = 1.5
# Overflow occurred for n = 1867, x = 1.5
# Overflow occurred for n = 1867, x = 1.5
# Overflow occurred for n = 1867, x = 1.5
# Overflow occurred for n = 1867, x = 1.5
# Overflow occurred for n = 1868, x = 1.5
# Overflow occurred for n = 1868, x = 1.5
# Overflow occurred for n = 1868, x = 1.5
# Overflow occurred for n = 1868, x = 1.5
# Overflow occurred for n = 1868, x = 1.5
# Overflow occurred for n = 1869, x = 1.5
# Overflow occurred for n = 1869, x = 1.5
# Overflow occurred for n = 1869, x = 1.5
# Overflow occurred for n = 1869, x = 1.5
# Overflow occurred for n = 1869, x = 1.5
# Overflow occurred for n = 1870, x = 1.5
# Overflow occurred for n = 1870, x = 1.5
# Overflow occurred for n = 1870, x = 1.5
# Overflow occurred for n = 1870, x = 1.5
# Overflow occurred for n = 1870, x = 1.5
# Overflow occurred for n = 1871, x = 1.5
# Overflow occurred for n = 1871, x = 1.5
# Overflow occurred for n = 1871, x = 1.5
# Overflow occurred for n = 1871, x = 1.5
# Overflow occurred for n = 1871, x = 1.5
# Overflow occurred for n = 1872, x = 1.5
# Overflow occurred for n = 1872, x = 1.5
# Overflow occurred for n = 1872, x = 1.5
# Overflow occurred for n = 1872, x = 1.5
# Overflow occurred for n = 1872, x = 1.5
# Overflow occurred for n = 1873, x = 1.5
# Overflow occurred for n = 1873, x = 1.5
# Overflow occurred for n = 1873, x = 1.5
# Overflow occurred for n = 1873, x = 1.5
# Overflow occurred for n = 1873, x = 1.5
# Overflow occurred for n = 1874, x = 1.5
# Overflow occurred for n = 1874, x = 1.5
# Overflow occurred for n = 1874, x = 1.5
# Overflow occurred for n = 1874, x = 1.5
# Overflow occurred for n = 1874, x = 1.5
# Overflow occurred for n = 1875, x = 1.5
# Overflow occurred for n = 1875, x = 1.5
# Overflow occurred for n = 1875, x = 1.5
# Overflow occurred for n = 1875, x = 1.5
# Overflow occurred for n = 1875, x = 1.5
# Overflow occurred for n = 1876, x = 1.5
# Overflow occurred for n = 1876, x = 1.5
# Overflow occurred for n = 1876, x = 1.5
# Overflow occurred for n = 1876, x = 1.5
# Overflow occurred for n = 1876, x = 1.5
# Overflow occurred for n = 1877, x = 1.5
# Overflow occurred for n = 1877, x = 1.5
# Overflow occurred for n = 1877, x = 1.5
# Overflow occurred for n = 1877, x = 1.5
# Overflow occurred for n = 1877, x = 1.5
# Overflow occurred for n = 1878, x = 1.5
# Overflow occurred for n = 1878, x = 1.5
# Overflow occurred for n = 1878, x = 1.5
# Overflow occurred for n = 1878, x = 1.5
# Overflow occurred for n = 1878, x = 1.5
# Overflow occurred for n = 1879, x = 1.5
# Overflow occurred for n = 1879, x = 1.5
# Overflow occurred for n = 1879, x = 1.5
# Overflow occurred for n = 1879, x = 1.5
# Overflow occurred for n = 1879, x = 1.5
# Overflow occurred for n = 1880, x = 1.5
# Overflow occurred for n = 1880, x = 1.5
# Overflow occurred for n = 1880, x = 1.5
# Overflow occurred for n = 1880, x = 1.5
# Overflow occurred for n = 1880, x = 1.5
# Overflow occurred for n = 1881, x = 1.5
# Overflow occurred for n = 1881, x = 1.5
# Overflow occurred for n = 1881, x = 1.5
# Overflow occurred for n = 1881, x = 1.5
# Overflow occurred for n = 1881, x = 1.5
# Overflow occurred for n = 1882, x = 1.5
# Overflow occurred for n = 1882, x = 1.5
# Overflow occurred for n = 1882, x = 1.5
# Overflow occurred for n = 1882, x = 1.5
# Overflow occurred for n = 1882, x = 1.5
# Overflow occurred for n = 1883, x = 1.5
# Overflow occurred for n = 1883, x = 1.5
# Overflow occurred for n = 1883, x = 1.5
# Overflow occurred for n = 1883, x = 1.5
# Overflow occurred for n = 1883, x = 1.5
# Overflow occurred for n = 1884, x = 1.5
# Overflow occurred for n = 1884, x = 1.5
# Overflow occurred for n = 1884, x = 1.5
# Overflow occurred for n = 1884, x = 1.5
# Overflow occurred for n = 1884, x = 1.5
# Overflow occurred for n = 1885, x = 1.5
# Overflow occurred for n = 1885, x = 1.5
# Overflow occurred for n = 1885, x = 1.5
# Overflow occurred for n = 1885, x = 1.5
# Overflow occurred for n = 1885, x = 1.5
# Overflow occurred for n = 1886, x = 1.5
# Overflow occurred for n = 1886, x = 1.5
# Overflow occurred for n = 1886, x = 1.5
# Overflow occurred for n = 1886, x = 1.5
# Overflow occurred for n = 1886, x = 1.5
# Overflow occurred for n = 1887, x = 1.5
# Overflow occurred for n = 1887, x = 1.5
# Overflow occurred for n = 1887, x = 1.5
# Overflow occurred for n = 1887, x = 1.5
# Overflow occurred for n = 1887, x = 1.5
# Overflow occurred for n = 1888, x = 1.5
# Overflow occurred for n = 1888, x = 1.5
# Overflow occurred for n = 1888, x = 1.5
# Overflow occurred for n = 1888, x = 1.5
# Overflow occurred for n = 1888, x = 1.5
# Overflow occurred for n = 1889, x = 1.5
# Overflow occurred for n = 1889, x = 1.5
# Overflow occurred for n = 1889, x = 1.5
# Overflow occurred for n = 1889, x = 1.5
# Overflow occurred for n = 1889, x = 1.5
# Overflow occurred for n = 1890, x = 1.5
# Overflow occurred for n = 1890, x = 1.5
# Overflow occurred for n = 1890, x = 1.5
# Overflow occurred for n = 1890, x = 1.5
# Overflow occurred for n = 1890, x = 1.5
# Overflow occurred for n = 1891, x = 1.5
# Overflow occurred for n = 1891, x = 1.5
# Overflow occurred for n = 1891, x = 1.5
# Overflow occurred for n = 1891, x = 1.5
# Overflow occurred for n = 1891, x = 1.5
# Overflow occurred for n = 1892, x = 1.5
# Overflow occurred for n = 1892, x = 1.5
# Overflow occurred for n = 1892, x = 1.5
# Overflow occurred for n = 1892, x = 1.5
# Overflow occurred for n = 1892, x = 1.5
# Overflow occurred for n = 1893, x = 1.5
# Overflow occurred for n = 1893, x = 1.5
# Overflow occurred for n = 1893, x = 1.5
# Overflow occurred for n = 1893, x = 1.5
# Overflow occurred for n = 1893, x = 1.5
# Overflow occurred for n = 1894, x = 1.5
# Overflow occurred for n = 1894, x = 1.5
# Overflow occurred for n = 1894, x = 1.5
# Overflow occurred for n = 1894, x = 1.5
# Overflow occurred for n = 1894, x = 1.5
# Overflow occurred for n = 1895, x = 1.5
# Overflow occurred for n = 1895, x = 1.5
# Overflow occurred for n = 1895, x = 1.5
# Overflow occurred for n = 1895, x = 1.5
# Overflow occurred for n = 1895, x = 1.5
# Overflow occurred for n = 1896, x = 1.5
# Overflow occurred for n = 1896, x = 1.5
# Overflow occurred for n = 1896, x = 1.5
# Overflow occurred for n = 1896, x = 1.5
# Overflow occurred for n = 1896, x = 1.5
# Overflow occurred for n = 1897, x = 1.5
# Overflow occurred for n = 1897, x = 1.5
# Overflow occurred for n = 1897, x = 1.5
# Overflow occurred for n = 1897, x = 1.5
# Overflow occurred for n = 1897, x = 1.5
# Overflow occurred for n = 1898, x = 1.5
# Overflow occurred for n = 1898, x = 1.5
# Overflow occurred for n = 1898, x = 1.5
# Overflow occurred for n = 1898, x = 1.5
# Overflow occurred for n = 1898, x = 1.5
# Overflow occurred for n = 1899, x = 1.5
# Overflow occurred for n = 1899, x = 1.5
# Overflow occurred for n = 1899, x = 1.5
# Overflow occurred for n = 1899, x = 1.5
# Overflow occurred for n = 1899, x = 1.5
# Overflow occurred for n = 1900, x = 1.5
# Overflow occurred for n = 1900, x = 1.5
# Overflow occurred for n = 1900, x = 1.5
# Overflow occurred for n = 1900, x = 1.5
# Overflow occurred for n = 1900, x = 1.5
# Overflow occurred for n = 1901, x = 1.5
# Overflow occurred for n = 1901, x = 1.5
# Overflow occurred for n = 1901, x = 1.5
# Overflow occurred for n = 1901, x = 1.5
# Overflow occurred for n = 1901, x = 1.5
# Overflow occurred for n = 1902, x = 1.5
# Overflow occurred for n = 1902, x = 1.5
# Overflow occurred for n = 1902, x = 1.5
# Overflow occurred for n = 1902, x = 1.5
# Overflow occurred for n = 1902, x = 1.5
# Overflow occurred for n = 1903, x = 1.5
# Overflow occurred for n = 1903, x = 1.5
# Overflow occurred for n = 1903, x = 1.5
# Overflow occurred for n = 1903, x = 1.5
# Overflow occurred for n = 1903, x = 1.5
# Overflow occurred for n = 1904, x = 1.5
# Overflow occurred for n = 1904, x = 1.5
# Overflow occurred for n = 1904, x = 1.5
# Overflow occurred for n = 1904, x = 1.5
# Overflow occurred for n = 1904, x = 1.5
# Overflow occurred for n = 1905, x = 1.5
# Overflow occurred for n = 1905, x = 1.5
# Overflow occurred for n = 1905, x = 1.5
# Overflow occurred for n = 1905, x = 1.5
# Overflow occurred for n = 1905, x = 1.5
# Overflow occurred for n = 1906, x = 1.5
# Overflow occurred for n = 1906, x = 1.5
# Overflow occurred for n = 1906, x = 1.5
# Overflow occurred for n = 1906, x = 1.5
# Overflow occurred for n = 1906, x = 1.5
# Overflow occurred for n = 1907, x = 1.5
# Overflow occurred for n = 1907, x = 1.5
# Overflow occurred for n = 1907, x = 1.5
# Overflow occurred for n = 1907, x = 1.5
# Overflow occurred for n = 1907, x = 1.5
# Overflow occurred for n = 1908, x = 1.5
# Overflow occurred for n = 1908, x = 1.5
# Overflow occurred for n = 1908, x = 1.5
# Overflow occurred for n = 1908, x = 1.5
# Overflow occurred for n = 1908, x = 1.5
# Overflow occurred for n = 1909, x = 1.5
# Overflow occurred for n = 1909, x = 1.5
# Overflow occurred for n = 1909, x = 1.5
# Overflow occurred for n = 1909, x = 1.5
# Overflow occurred for n = 1909, x = 1.5
# Overflow occurred for n = 1910, x = 1.5
# Overflow occurred for n = 1910, x = 1.5
# Overflow occurred for n = 1910, x = 1.5
# Overflow occurred for n = 1910, x = 1.5
# Overflow occurred for n = 1910, x = 1.5
# Overflow occurred for n = 1911, x = 1.5
# Overflow occurred for n = 1911, x = 1.5
# Overflow occurred for n = 1911, x = 1.5
# Overflow occurred for n = 1911, x = 1.5
# Overflow occurred for n = 1911, x = 1.5
# Overflow occurred for n = 1912, x = 1.5
# Overflow occurred for n = 1912, x = 1.5
# Overflow occurred for n = 1912, x = 1.5
# Overflow occurred for n = 1912, x = 1.5
# Overflow occurred for n = 1912, x = 1.5
# Overflow occurred for n = 1913, x = 1.5
# Overflow occurred for n = 1913, x = 1.5
# Overflow occurred for n = 1913, x = 1.5
# Overflow occurred for n = 1913, x = 1.5
# Overflow occurred for n = 1913, x = 1.5
# Overflow occurred for n = 1914, x = 1.5
# Overflow occurred for n = 1914, x = 1.5
# Overflow occurred for n = 1914, x = 1.5
# Overflow occurred for n = 1914, x = 1.5
# Overflow occurred for n = 1914, x = 1.5
# Overflow occurred for n = 1915, x = 1.5
# Overflow occurred for n = 1915, x = 1.5
# Overflow occurred for n = 1915, x = 1.5
# Overflow occurred for n = 1915, x = 1.5
# Overflow occurred for n = 1915, x = 1.5
# Overflow occurred for n = 1916, x = 1.5
# Overflow occurred for n = 1916, x = 1.5
# Overflow occurred for n = 1916, x = 1.5
# Overflow occurred for n = 1916, x = 1.5
# Overflow occurred for n = 1916, x = 1.5
# Overflow occurred for n = 1917, x = 1.5
# Overflow occurred for n = 1917, x = 1.5
# Overflow occurred for n = 1917, x = 1.5
# Overflow occurred for n = 1917, x = 1.5
# Overflow occurred for n = 1917, x = 1.5
# Overflow occurred for n = 1918, x = 1.5
# Overflow occurred for n = 1918, x = 1.5
# Overflow occurred for n = 1918, x = 1.5
# Overflow occurred for n = 1918, x = 1.5
# Overflow occurred for n = 1918, x = 1.5
# Overflow occurred for n = 1919, x = 1.5
# Overflow occurred for n = 1919, x = 1.5
# Overflow occurred for n = 1919, x = 1.5
# Overflow occurred for n = 1919, x = 1.5
# Overflow occurred for n = 1919, x = 1.5
# Overflow occurred for n = 1920, x = 1.5
# Overflow occurred for n = 1920, x = 1.5
# Overflow occurred for n = 1920, x = 1.5
# Overflow occurred for n = 1920, x = 1.5
# Overflow occurred for n = 1920, x = 1.5
# Overflow occurred for n = 1921, x = 1.5
# Overflow occurred for n = 1921, x = 1.5
# Overflow occurred for n = 1921, x = 1.5
# Overflow occurred for n = 1921, x = 1.5
# Overflow occurred for n = 1921, x = 1.5
# Overflow occurred for n = 1922, x = 1.5
# Overflow occurred for n = 1922, x = 1.5
# Overflow occurred for n = 1922, x = 1.5
# Overflow occurred for n = 1922, x = 1.5
# Overflow occurred for n = 1922, x = 1.5
# Overflow occurred for n = 1923, x = 1.5
# Overflow occurred for n = 1923, x = 1.5
# Overflow occurred for n = 1923, x = 1.5
# Overflow occurred for n = 1923, x = 1.5
# Overflow occurred for n = 1923, x = 1.5
# Overflow occurred for n = 1924, x = 1.5
# Overflow occurred for n = 1924, x = 1.5
# Overflow occurred for n = 1924, x = 1.5
# Overflow occurred for n = 1924, x = 1.5
# Overflow occurred for n = 1924, x = 1.5
# Overflow occurred for n = 1925, x = 1.5
# Overflow occurred for n = 1925, x = 1.5
# Overflow occurred for n = 1925, x = 1.5
# Overflow occurred for n = 1925, x = 1.5
# Overflow occurred for n = 1925, x = 1.5
# Overflow occurred for n = 1926, x = 1.5
# Overflow occurred for n = 1926, x = 1.5
# Overflow occurred for n = 1926, x = 1.5
# Overflow occurred for n = 1926, x = 1.5
# Overflow occurred for n = 1926, x = 1.5
# Overflow occurred for n = 1927, x = 1.5
# Overflow occurred for n = 1927, x = 1.5
# Overflow occurred for n = 1927, x = 1.5
# Overflow occurred for n = 1927, x = 1.5
# Overflow occurred for n = 1927, x = 1.5
# Overflow occurred for n = 1928, x = 1.5
# Overflow occurred for n = 1928, x = 1.5
# Overflow occurred for n = 1928, x = 1.5
# Overflow occurred for n = 1928, x = 1.5
# Overflow occurred for n = 1928, x = 1.5
# Overflow occurred for n = 1929, x = 1.5
# Overflow occurred for n = 1929, x = 1.5
# Overflow occurred for n = 1929, x = 1.5
# Overflow occurred for n = 1929, x = 1.5
# Overflow occurred for n = 1929, x = 1.5
# Overflow occurred for n = 1930, x = 1.5
# Overflow occurred for n = 1930, x = 1.5
# Overflow occurred for n = 1930, x = 1.5
# Overflow occurred for n = 1930, x = 1.5
# Overflow occurred for n = 1930, x = 1.5
# Overflow occurred for n = 1931, x = 1.5
# Overflow occurred for n = 1931, x = 1.5
# Overflow occurred for n = 1931, x = 1.5
# Overflow occurred for n = 1931, x = 1.5
# Overflow occurred for n = 1931, x = 1.5
# Overflow occurred for n = 1932, x = 1.5
# Overflow occurred for n = 1932, x = 1.5
# Overflow occurred for n = 1932, x = 1.5
# Overflow occurred for n = 1932, x = 1.5
# Overflow occurred for n = 1932, x = 1.5
# Overflow occurred for n = 1933, x = 1.5
# Overflow occurred for n = 1933, x = 1.5
# Overflow occurred for n = 1933, x = 1.5
# Overflow occurred for n = 1933, x = 1.5
# Overflow occurred for n = 1933, x = 1.5
# Overflow occurred for n = 1934, x = 1.5
# Overflow occurred for n = 1934, x = 1.5
# Overflow occurred for n = 1934, x = 1.5
# Overflow occurred for n = 1934, x = 1.5
# Overflow occurred for n = 1934, x = 1.5
# Overflow occurred for n = 1935, x = 1.5
# Overflow occurred for n = 1935, x = 1.5
# Overflow occurred for n = 1935, x = 1.5
# Overflow occurred for n = 1935, x = 1.5
# Overflow occurred for n = 1935, x = 1.5
# Overflow occurred for n = 1936, x = 1.5
# Overflow occurred for n = 1936, x = 1.5
# Overflow occurred for n = 1936, x = 1.5
# Overflow occurred for n = 1936, x = 1.5
# Overflow occurred for n = 1936, x = 1.5
# Overflow occurred for n = 1937, x = 1.5
# Overflow occurred for n = 1937, x = 1.5
# Overflow occurred for n = 1937, x = 1.5
# Overflow occurred for n = 1937, x = 1.5
# Overflow occurred for n = 1937, x = 1.5
# Overflow occurred for n = 1938, x = 1.5
# Overflow occurred for n = 1938, x = 1.5
# Overflow occurred for n = 1938, x = 1.5
# Overflow occurred for n = 1938, x = 1.5
# Overflow occurred for n = 1938, x = 1.5
# Overflow occurred for n = 1939, x = 1.5
# Overflow occurred for n = 1939, x = 1.5
# Overflow occurred for n = 1939, x = 1.5
# Overflow occurred for n = 1939, x = 1.5
# Overflow occurred for n = 1939, x = 1.5
# Overflow occurred for n = 1940, x = 1.5
# Overflow occurred for n = 1940, x = 1.5
# Overflow occurred for n = 1940, x = 1.5
# Overflow occurred for n = 1940, x = 1.5
# Overflow occurred for n = 1940, x = 1.5
# Overflow occurred for n = 1941, x = 1.5
# Overflow occurred for n = 1941, x = 1.5
# Overflow occurred for n = 1941, x = 1.5
# Overflow occurred for n = 1941, x = 1.5
# Overflow occurred for n = 1941, x = 1.5
# Overflow occurred for n = 1942, x = 1.5
# Overflow occurred for n = 1942, x = 1.5
# Overflow occurred for n = 1942, x = 1.5
# Overflow occurred for n = 1942, x = 1.5
# Overflow occurred for n = 1942, x = 1.5
# Overflow occurred for n = 1943, x = 1.5
# Overflow occurred for n = 1943, x = 1.5
# Overflow occurred for n = 1943, x = 1.5
# Overflow occurred for n = 1943, x = 1.5
# Overflow occurred for n = 1943, x = 1.5
# Overflow occurred for n = 1944, x = 1.5
# Overflow occurred for n = 1944, x = 1.5
# Overflow occurred for n = 1944, x = 1.5
# Overflow occurred for n = 1944, x = 1.5
# Overflow occurred for n = 1944, x = 1.5
# Overflow occurred for n = 1945, x = 1.5
# Overflow occurred for n = 1945, x = 1.5
# Overflow occurred for n = 1945, x = 1.5
# Overflow occurred for n = 1945, x = 1.5
# Overflow occurred for n = 1945, x = 1.5
# Overflow occurred for n = 1946, x = 1.5
# Overflow occurred for n = 1946, x = 1.5
# Overflow occurred for n = 1946, x = 1.5
# Overflow occurred for n = 1946, x = 1.5
# Overflow occurred for n = 1946, x = 1.5
# Overflow occurred for n = 1947, x = 1.5
# Overflow occurred for n = 1947, x = 1.5
# Overflow occurred for n = 1947, x = 1.5
# Overflow occurred for n = 1947, x = 1.5
# Overflow occurred for n = 1947, x = 1.5
# Overflow occurred for n = 1948, x = 1.5
# Overflow occurred for n = 1948, x = 1.5
# Overflow occurred for n = 1948, x = 1.5
# Overflow occurred for n = 1948, x = 1.5
# Overflow occurred for n = 1948, x = 1.5
# Overflow occurred for n = 1949, x = 1.5
# Overflow occurred for n = 1949, x = 1.5
# Overflow occurred for n = 1949, x = 1.5
# Overflow occurred for n = 1949, x = 1.5
# Overflow occurred for n = 1949, x = 1.5
# Overflow occurred for n = 1950, x = 1.5
# Overflow occurred for n = 1950, x = 1.5
# Overflow occurred for n = 1950, x = 1.5
# Overflow occurred for n = 1950, x = 1.5
# Overflow occurred for n = 1950, x = 1.5
# Overflow occurred for n = 1951, x = 1.5
# Overflow occurred for n = 1951, x = 1.5
# Overflow occurred for n = 1951, x = 1.5
# Overflow occurred for n = 1951, x = 1.5
# Overflow occurred for n = 1951, x = 1.5
# Overflow occurred for n = 1952, x = 1.5
# Overflow occurred for n = 1952, x = 1.5
# Overflow occurred for n = 1952, x = 1.5
# Overflow occurred for n = 1952, x = 1.5
# Overflow occurred for n = 1952, x = 1.5
# Overflow occurred for n = 1953, x = 1.5
# Overflow occurred for n = 1953, x = 1.5
# Overflow occurred for n = 1953, x = 1.5
# Overflow occurred for n = 1953, x = 1.5
# Overflow occurred for n = 1953, x = 1.5
# Overflow occurred for n = 1954, x = 1.5
# Overflow occurred for n = 1954, x = 1.5
# Overflow occurred for n = 1954, x = 1.5
# Overflow occurred for n = 1954, x = 1.5
# Overflow occurred for n = 1954, x = 1.5
# Overflow occurred for n = 1955, x = 1.5
# Overflow occurred for n = 1955, x = 1.5
# Overflow occurred for n = 1955, x = 1.5
# Overflow occurred for n = 1955, x = 1.5
# Overflow occurred for n = 1955, x = 1.5
# Overflow occurred for n = 1956, x = 1.5
# Overflow occurred for n = 1956, x = 1.5
# Overflow occurred for n = 1956, x = 1.5
# Overflow occurred for n = 1956, x = 1.5
# Overflow occurred for n = 1956, x = 1.5
# Overflow occurred for n = 1957, x = 1.5
# Overflow occurred for n = 1957, x = 1.5
# Overflow occurred for n = 1957, x = 1.5
# Overflow occurred for n = 1957, x = 1.5
# Overflow occurred for n = 1957, x = 1.5
# Overflow occurred for n = 1958, x = 1.5
# Overflow occurred for n = 1958, x = 1.5
# Overflow occurred for n = 1958, x = 1.5
# Overflow occurred for n = 1958, x = 1.5
# Overflow occurred for n = 1958, x = 1.5
# Overflow occurred for n = 1959, x = 1.5
# Overflow occurred for n = 1959, x = 1.5
# Overflow occurred for n = 1959, x = 1.5
# Overflow occurred for n = 1959, x = 1.5
# Overflow occurred for n = 1959, x = 1.5
# Overflow occurred for n = 1960, x = 1.5
# Overflow occurred for n = 1960, x = 1.5
# Overflow occurred for n = 1960, x = 1.5
# Overflow occurred for n = 1960, x = 1.5
# Overflow occurred for n = 1960, x = 1.5
# Overflow occurred for n = 1961, x = 1.5
# Overflow occurred for n = 1961, x = 1.5
# Overflow occurred for n = 1961, x = 1.5
# Overflow occurred for n = 1961, x = 1.5
# Overflow occurred for n = 1961, x = 1.5
# Overflow occurred for n = 1962, x = 1.5
# Overflow occurred for n = 1962, x = 1.5
# Overflow occurred for n = 1962, x = 1.5
# Overflow occurred for n = 1962, x = 1.5
# Overflow occurred for n = 1962, x = 1.5
# Overflow occurred for n = 1963, x = 1.5
# Overflow occurred for n = 1963, x = 1.5
# Overflow occurred for n = 1963, x = 1.5
# Overflow occurred for n = 1963, x = 1.5
# Overflow occurred for n = 1963, x = 1.5
# Overflow occurred for n = 1964, x = 1.5
# Overflow occurred for n = 1964, x = 1.5
# Overflow occurred for n = 1964, x = 1.5
# Overflow occurred for n = 1964, x = 1.5
# Overflow occurred for n = 1964, x = 1.5
# Overflow occurred for n = 1965, x = 1.5
# Overflow occurred for n = 1965, x = 1.5
# Overflow occurred for n = 1965, x = 1.5
# Overflow occurred for n = 1965, x = 1.5
# Overflow occurred for n = 1965, x = 1.5
# Overflow occurred for n = 1966, x = 1.5
# Overflow occurred for n = 1966, x = 1.5
# Overflow occurred for n = 1966, x = 1.5
# Overflow occurred for n = 1966, x = 1.5
# Overflow occurred for n = 1966, x = 1.5
# Overflow occurred for n = 1967, x = 1.5
# Overflow occurred for n = 1967, x = 1.5
# Overflow occurred for n = 1967, x = 1.5
# Overflow occurred for n = 1967, x = 1.5
# Overflow occurred for n = 1967, x = 1.5
# Overflow occurred for n = 1968, x = 1.5
# Overflow occurred for n = 1968, x = 1.5
# Overflow occurred for n = 1968, x = 1.5
# Overflow occurred for n = 1968, x = 1.5
# Overflow occurred for n = 1968, x = 1.5
# Overflow occurred for n = 1969, x = 1.5
# Overflow occurred for n = 1969, x = 1.5
# Overflow occurred for n = 1969, x = 1.5
# Overflow occurred for n = 1969, x = 1.5
# Overflow occurred for n = 1969, x = 1.5
# Overflow occurred for n = 1970, x = 1.5
# Overflow occurred for n = 1970, x = 1.5
# Overflow occurred for n = 1970, x = 1.5
# Overflow occurred for n = 1970, x = 1.5
# Overflow occurred for n = 1970, x = 1.5
# Overflow occurred for n = 1971, x = 1.5
# Overflow occurred for n = 1971, x = 1.5
# Overflow occurred for n = 1971, x = 1.5
# Overflow occurred for n = 1971, x = 1.5
# Overflow occurred for n = 1971, x = 1.5
# Overflow occurred for n = 1972, x = 1.5
# Overflow occurred for n = 1972, x = 1.5
# Overflow occurred for n = 1972, x = 1.5
# Overflow occurred for n = 1972, x = 1.5
# Overflow occurred for n = 1972, x = 1.5
# Overflow occurred for n = 1973, x = 1.5
# Overflow occurred for n = 1973, x = 1.5
# Overflow occurred for n = 1973, x = 1.5
# Overflow occurred for n = 1973, x = 1.5
# Overflow occurred for n = 1973, x = 1.5
# Overflow occurred for n = 1974, x = 1.5
# Overflow occurred for n = 1974, x = 1.5
# Overflow occurred for n = 1974, x = 1.5
# Overflow occurred for n = 1974, x = 1.5
# Overflow occurred for n = 1974, x = 1.5
# Overflow occurred for n = 1975, x = 1.5
# Overflow occurred for n = 1975, x = 1.5
# Overflow occurred for n = 1975, x = 1.5
# Overflow occurred for n = 1975, x = 1.5
# Overflow occurred for n = 1975, x = 1.5
# Overflow occurred for n = 1976, x = 1.5
# Overflow occurred for n = 1976, x = 1.5
# Overflow occurred for n = 1976, x = 1.5
# Overflow occurred for n = 1976, x = 1.5
# Overflow occurred for n = 1976, x = 1.5
# Overflow occurred for n = 1977, x = 1.5
# Overflow occurred for n = 1977, x = 1.5
# Overflow occurred for n = 1977, x = 1.5
# Overflow occurred for n = 1977, x = 1.5
# Overflow occurred for n = 1977, x = 1.5
# Overflow occurred for n = 1978, x = 1.5
# Overflow occurred for n = 1978, x = 1.5
# Overflow occurred for n = 1978, x = 1.5
# Overflow occurred for n = 1978, x = 1.5
# Overflow occurred for n = 1978, x = 1.5
# Overflow occurred for n = 1979, x = 1.5
# Overflow occurred for n = 1979, x = 1.5
# Overflow occurred for n = 1979, x = 1.5
# Overflow occurred for n = 1979, x = 1.5
# Overflow occurred for n = 1979, x = 1.5
# Overflow occurred for n = 1980, x = 1.5
# Overflow occurred for n = 1980, x = 1.5
# Overflow occurred for n = 1980, x = 1.5
# Overflow occurred for n = 1980, x = 1.5
# Overflow occurred for n = 1980, x = 1.5
# Overflow occurred for n = 1981, x = 1.5
# Overflow occurred for n = 1981, x = 1.5
# Overflow occurred for n = 1981, x = 1.5
# Overflow occurred for n = 1981, x = 1.5
# Overflow occurred for n = 1981, x = 1.5
# Overflow occurred for n = 1982, x = 1.5
# Overflow occurred for n = 1982, x = 1.5
# Overflow occurred for n = 1982, x = 1.5
# Overflow occurred for n = 1982, x = 1.5
# Overflow occurred for n = 1982, x = 1.5
# Overflow occurred for n = 1983, x = 1.5
# Overflow occurred for n = 1983, x = 1.5
# Overflow occurred for n = 1983, x = 1.5
# Overflow occurred for n = 1983, x = 1.5
# Overflow occurred for n = 1983, x = 1.5
# Overflow occurred for n = 1984, x = 1.5
# Overflow occurred for n = 1984, x = 1.5
# Overflow occurred for n = 1984, x = 1.5
# Overflow occurred for n = 1984, x = 1.5
# Overflow occurred for n = 1984, x = 1.5
# Overflow occurred for n = 1985, x = 1.5
# Overflow occurred for n = 1985, x = 1.5
# Overflow occurred for n = 1985, x = 1.5
# Overflow occurred for n = 1985, x = 1.5
# Overflow occurred for n = 1985, x = 1.5
# Overflow occurred for n = 1986, x = 1.5
# Overflow occurred for n = 1986, x = 1.5
# Overflow occurred for n = 1986, x = 1.5
# Overflow occurred for n = 1986, x = 1.5
# Overflow occurred for n = 1986, x = 1.5
# Overflow occurred for n = 1987, x = 1.5
# Overflow occurred for n = 1987, x = 1.5
# Overflow occurred for n = 1987, x = 1.5
# Overflow occurred for n = 1987, x = 1.5
# Overflow occurred for n = 1987, x = 1.5
# Overflow occurred for n = 1988, x = 1.5
# Overflow occurred for n = 1988, x = 1.5
# Overflow occurred for n = 1988, x = 1.5
# Overflow occurred for n = 1988, x = 1.5
# Overflow occurred for n = 1988, x = 1.5
# Overflow occurred for n = 1989, x = 1.5
# Overflow occurred for n = 1989, x = 1.5
# Overflow occurred for n = 1989, x = 1.5
# Overflow occurred for n = 1989, x = 1.5
# Overflow occurred for n = 1989, x = 1.5
# Overflow occurred for n = 1990, x = 1.5
# Overflow occurred for n = 1990, x = 1.5
# Overflow occurred for n = 1990, x = 1.5
# Overflow occurred for n = 1990, x = 1.5
# Overflow occurred for n = 1990, x = 1.5
# Overflow occurred for n = 1991, x = 1.5
# Overflow occurred for n = 1991, x = 1.5
# Overflow occurred for n = 1991, x = 1.5
# Overflow occurred for n = 1991, x = 1.5
# Overflow occurred for n = 1991, x = 1.5
# Overflow occurred for n = 1992, x = 1.5
# Overflow occurred for n = 1992, x = 1.5
# Overflow occurred for n = 1992, x = 1.5
# Overflow occurred for n = 1992, x = 1.5
# Overflow occurred for n = 1992, x = 1.5
# Overflow occurred for n = 1993, x = 1.5
# Overflow occurred for n = 1993, x = 1.5
# Overflow occurred for n = 1993, x = 1.5
# Overflow occurred for n = 1993, x = 1.5
# Overflow occurred for n = 1993, x = 1.5
# Overflow occurred for n = 1994, x = 1.5
# Overflow occurred for n = 1994, x = 1.5
# Overflow occurred for n = 1994, x = 1.5
# Overflow occurred for n = 1994, x = 1.5
# Overflow occurred for n = 1994, x = 1.5
# Overflow occurred for n = 1995, x = 1.5
# Overflow occurred for n = 1995, x = 1.5
# Overflow occurred for n = 1995, x = 1.5
# Overflow occurred for n = 1995, x = 1.5
# Overflow occurred for n = 1995, x = 1.5
# Overflow occurred for n = 1996, x = 1.5
# Overflow occurred for n = 1996, x = 1.5
# Overflow occurred for n = 1996, x = 1.5
# Overflow occurred for n = 1996, x = 1.5
# Overflow occurred for n = 1996, x = 1.5
# Overflow occurred for n = 1997, x = 1.5
# Overflow occurred for n = 1997, x = 1.5
# Overflow occurred for n = 1997, x = 1.5
# Overflow occurred for n = 1997, x = 1.5
# Overflow occurred for n = 1997, x = 1.5
# Overflow occurred for n = 1998, x = 1.5
# Overflow occurred for n = 1998, x = 1.5
# Overflow occurred for n = 1998, x = 1.5
# Overflow occurred for n = 1998, x = 1.5
# Overflow occurred for n = 1998, x = 1.5
# Overflow occurred for n = 1999, x = 1.5
# Overflow occurred for n = 1999, x = 1.5
# Overflow occurred for n = 1999, x = 1.5
# Overflow occurred for n = 1999, x = 1.5
# Overflow occurred for n = 1999, x = 1.5
# Overflow occurred for n = 2000, x = 1.5
# Overflow occurred for n = 2000, x = 1.5
# Overflow occurred for n = 2000, x = 1.5
# Overflow occurred for n = 2000, x = 1.5
# Overflow occurred for n = 2000, x = 1.5

# %% [markdown]
# The experimental results show that both the direct calculation and Horner's method exhibit linear growth in execution time, consistent with their O(n) complexity. However, the direct calculation occasionally leads to overflow errors due to large intermediate values when computing powers of x, whereas Horner’s method avoids such issues by reducing the number of multiplications and powers. Additionally, as predicted by theory, Horner's method takes less time in practice, as it minimizes redundant calculations, which was confirmed by the experimental results.

# %% [markdown]
# # II. Generate random matrices 𝐴 and 𝐵 of size 𝑛 × 𝑛 with non-negative elements.
# # Find the usual matrix product for 𝐴 and 𝐵. **bold text**

# %% [markdown]
# Matrix multiplication involves multiplying two matrices
# A and
# B to produce a result matrix
# C, where each element of
# C is the dot product of corresponding rows and columns from
# A and
# B. The standard algorithm for matrix multiplication has a time complexity of
# O(n^
# 3
#  ), where
# n is the dimension of the square matrices being multiplied.

# %%
# Function to generate a random matrix of size n x n
def generate_random_matrix(n):
    return np.random.randint(0, 10, size=(n, n))

# Function to multiply two matrices using standard method
def matrix_multiply(A, B):
    return np.dot(A, B)

# Storage for execution times
execution_times_matrix_multiply = []

# %%
# Measure execution time for matrix multiplication for each n
for n in range(1, 2011):
    A = generate_random_matrix(n)  # Generate random matrix A
    B = generate_random_matrix(n)  # Generate random matrix B

    # Measure time for matrix multiplication
    start_time = time.perf_counter()  # Start time
    for _ in range(5):  # Run 5 times to average the time
        _ = matrix_multiply(A, B)  # Multiply matrices
    end_time = time.perf_counter()  # End time

    # Calculate the average time taken for matrix multiplication
    average_time = (end_time - start_time) / 5
    execution_times_matrix_multiply.append(average_time)  # Store the average time
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-9f2e84179553> in <cell line: 2>()
#       7     start_time = time.perf_counter()  # Start time
#       8     for _ in range(5):  # Run 5 times to average the time
# ----> 9         _ = matrix_multiply(A, B)  # Multiply matrices
#      10     end_time = time.perf_counter()  # End time
#      11
#
# <ipython-input-39-36117cd3b481> in matrix_multiply(A, B)
#       5 # Function to multiply two matrices using standard method
#       6 def matrix_multiply(A, B):
# ----> 7     return np.dot(A, B)
#       8
#       9 # Storage for execution times
#
# KeyboardInterrupt:

# %% [markdown]
# Here I interrupted the code block as it took almost 90mins to multiply 1162 matrices and plotted the graph for the collected values.

# %%
# Plot the execution time for matrix multiplication
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(execution_times_matrix_multiply) + 1), execution_times_matrix_multiply, label="Matrix Multiplication", color="green")
plt.xlabel("Matrix Dimension (n)")
plt.ylabel("Average Execution Time (seconds)")
plt.title("Execution Time of Matrix Multiplication")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The graph shows an increase in execution time as the size of the matrices grows, which aligns with the theoretical expectation of
# O(n^
# 3
#  ) time complexity for matrix multiplication. As the matrix dimension increases, the number of operations required grows cubically, leading to higher computation time, as observed in the experiment.

# %% [markdown]
# # Conclusion:

# %% [markdown]
# In these task, different algorithms use various data structures and techniques to perform their operations efficiently. For example, when calculating the sum or product of elements in a vector, a simple array or list is used to store the data. The bubble sort algorithm, which sorts the vector, relies on repeatedly swapping elements within the list, making use of nested loops. Quick sort, on the other hand, uses a divide-and-conquer strategy, where the vector is split into smaller parts, sorted, and then merged. Timsort, which is the default sorting algorithm in Python, is a hybrid of merge sort and insertion sort, making it very efficient for real-world data. For matrix multiplication, we use a 2D list (matrix) and perform row-by-column multiplication.
